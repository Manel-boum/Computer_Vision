# %%
# Installer les bibliothèques (à exécuter une seule fois)
# !pip install easyocr
# !pip install matplotlib
# !pip install opencv-python-headless

# Importer les bibliothèques
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

import cv2
import easyocr
import matplotlib.pyplot as plt 

# read image
image_path = r'C:\Users\HP\Desktop\Computer_Vision_Engineer\4.Text_detection_with_Python_and_Opencv_OCR_using_EasyOCR\data\test3.png'
img = cv2.imread(image_path)

# check if the image has been read correctly
if img is None:
    raise ValueError(f"Image not found at {image_path}. Please check the path.")

# Instance text detector
reader = easyocr.Reader(['en'], gpu=False)

threshold = 0.25 
# Detect text on image 
text_ = reader.readtext(img)

# draw bbox and text
for t in text_: 
    print(t)
    
    bbox, text, score = t
    
    if score > threshold: 
        cv2.rectangle(img, bbox[0], bbox[2], (0, 255, 0), 5)
        cv2.putText(img, text, bbox[0], cv2.FONT_HERSHEY_COMPLEX, 0.65, (255, 0, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ...
# Using CPU. Note: This module is much faster with a GPU.
# ...
# ([[134, 190], [464, 190], [464, 266], [134, 266]], 'CAUTION', 0.9998712379439514)
# ([[188, 300], [412, 300], [412, 354], [188, 354]], 'MAINTAIN', 0.9999742059909161)
# ([[216, 360], [386, 360], [386, 416], [216, 416]], 'SOCIAL', 0.9994896000120571)
# ([[162, 417], [441, 417], [441, 479], [162, 479]], 'DISTANCING', 0.9997321399247189)
# ([[234, 522], [372, 522], [372, 552], [234, 552]], 'AT LEAST', 0.66517512368568)
# ([[265, 553], [341, 553], [341, 591], [265, 591]], '6ft.', 0.5638235211372375)
# ([[140, 643], [463, 643], [463, 682], [140, 682]], 'DISTANCE FROM OTHERS', 0.9714368152331847)
